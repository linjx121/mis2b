# %% [markdown]
# <a href="https://colab.research.google.com/github/linjx121/mis2b/blob/main/%E6%AC%A1%E6%96%B9%E6%A0%B9%E8%99%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input("x:"))
opt = input("運算:∧(次方)✓(根號)")
y = int(input("y:"))

if opt == "∧":
  result = x ** y
elif opt == "✓":
  if y == 0:
    result =="數學不能開0次方根"
  else:
    result = x ** (1/y)

else:
  result ="請輸入∧或✓"
print(result)
# Out:
# x:10
# 運算:∧(次方)✓(根號)∧
# y:3
# 1000
